# %%
import pandas as pd 
import plotly.express as px

# %%
df = pd.read_csv('ekkolodd.csv')
#df = df[:10000]
print(df)
# Out:
#                   sample start time  distance  confidence
# 0       09 Aug 2022 13:15:16 +0000       6751         100
# 1       09 Aug 2022 13:15:16 +0000       6751         100
# 2       09 Aug 2022 13:15:16 +0000       6751         100
# 3       09 Aug 2022 13:15:16 +0000       6751         100
# 4       09 Aug 2022 13:15:16 +0000       6751         100
# ...                             ...       ...         ...
# 61281   25 Aug 2022 10:28:29 +0000       6227           0
# 61282   25 Aug 2022 10:28:29 +0000       6227           0
# 61283   25 Aug 2022 10:28:29 +0000       6722           0
# 61284   25 Aug 2022 10:28:29 +0000       6722           0
# 61285   25 Aug 2022 10:28:29 +0000       6722           0
#
# [61286 rows x 3 columns]

# %%
test = df.loc[df['sample start time'] == ' 09 Aug 2022 13:37:37 +0000 ']

# %%
df2 = df.loc[df['confidence'] >= 99]

# %%
fig = px.scatter(df2, x = 'sample start time', y = 'distance', title='the distance')
fig.show()
# Out:
# <div>                            <div id="a785a18e-db88-4c4e-b763-bcacd26b6b5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a785a18e-db88-4c4e-b763-bcacd26b6b5b")) {                    Plotly.newPlot(                        "a785a18e-db88-4c4e-b763-bcacd26b6b5b",                        [{"hovertemplate":"sample start time=%{x}<br>distance=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[" 09 Aug 2022 13:15:16 +0000 "," 09 Aug 2022 13:15:16 +0000 "," 09 Aug 2022 13:15:16 +0000 "," 09 Aug 2022 13:15:16 +0000 "," 09 Aug 2022 13:15:16 +0000 "," 09 Aug 2022 13:15:16 +0000 "," 09 Aug 2022 13:15:16 +0000 "," 09 Aug 2022 13:15:16 +0000 "," 09 Aug 2022 13:15:16 +0000 "
# ...

# %%
print(test)
# Out:
#                  sample start time  distance  confidence
# 1200   09 Aug 2022 13:37:37 +0000      13258           0
# 1201   09 Aug 2022 13:37:37 +0000      13258           0
# 1202   09 Aug 2022 13:37:37 +0000      14860           0
# 1203   09 Aug 2022 13:37:37 +0000      14860           0
# 1204   09 Aug 2022 13:37:37 +0000      14860           0
# ...                            ...       ...         ...
# 3521   09 Aug 2022 13:37:37 +0000       6750         100
# 3522   09 Aug 2022 13:37:37 +0000       6750         100
# 3523   09 Aug 2022 13:37:37 +0000       6751         100
# 3524   09 Aug 2022 13:37:37 +0000       6751         100
# 3525   09 Aug 2022 13:37:37 +0000       6751         100
#
# [2326 rows x 3 columns]

# %%
fig2 = px.scatter(test, x = 'sample start time', y = 'distance', title='the distance')
fig2.show()
# Out:
# <div>                            <div id="012d1fb7-89ba-4ccd-aeb1-55a5a49e5aa0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("012d1fb7-89ba-4ccd-aeb1-55a5a49e5aa0")) {                    Plotly.newPlot(                        "012d1fb7-89ba-4ccd-aeb1-55a5a49e5aa0",                        [{"hovertemplate":"sample start time=%{x}<br>distance=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[" 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "
# ...

# %%
test2 = test.loc[test['confidence'] >= 99]
print(test2)
# Out:
#                  sample start time  distance  confidence
# 2431   09 Aug 2022 13:37:37 +0000       6688         100
# 2432   09 Aug 2022 13:37:37 +0000       6688         100
# 2433   09 Aug 2022 13:37:37 +0000       6688         100
# 2434   09 Aug 2022 13:37:37 +0000       6710         100
# 2435   09 Aug 2022 13:37:37 +0000       6710         100
# ...                            ...       ...         ...
# 3521   09 Aug 2022 13:37:37 +0000       6750         100
# 3522   09 Aug 2022 13:37:37 +0000       6750         100
# 3523   09 Aug 2022 13:37:37 +0000       6751         100
# 3524   09 Aug 2022 13:37:37 +0000       6751         100
# 3525   09 Aug 2022 13:37:37 +0000       6751         100
#
# [1095 rows x 3 columns]

# %%
fig3 = px.scatter(test2, x = 'sample start time', y = 'distance', title='the distance')
fig3.show()
# Out:
# <div>                            <div id="6ac7e599-1d96-4d7d-b52d-836318b05b4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ac7e599-1d96-4d7d-b52d-836318b05b4a")) {                    Plotly.newPlot(                        "6ac7e599-1d96-4d7d-b52d-836318b05b4a",                        [{"hovertemplate":"sample start time=%{x}<br>distance=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[" 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "," 09 Aug 2022 13:37:37 +0000 "
# ...
